# %%
# Import Dependencies
# %matplotlib inline
import pandas as pd
import tweepy
import json
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import and Initialize Sentiment Analyzer

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#Just wanted to have some extra fun with this one
#Hope that's ok 

# Target 
target_user = "TheOnion"

# Counter
count = 1

# Variables for holding sentiments
onion_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
onion_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in onion_public_tweets:
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    onion_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
onion_sentiments_df = pd.DataFrame.from_dict(onion_sentiments)
onion_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Wed Aug 29 01:16:00 +0000 2018     0.000    1.000     0.000
# 1    0.0000  Wed Aug 29 00:39:06 +0000 2018     0.000    1.000     0.000
# 2    0.1779  Wed Aug 29 00:02:03 +0000 2018     0.146    0.662     0.192
# 3    0.0000  Tue Aug 28 23:25:05 +0000 2018     0.000    1.000     0.000
# 4    0.0000  Tue Aug 28 22:48:01 +0000 2018     0.000    1.000     0.000
#
#      Source                                               Text  Tweets Ago
# 0  TheOnion  Tips For Making The Most Of Your Next Doctor’s...           1
# 1  TheOnion  Dad Returns From Business Trip With Exotic Gif...           2
# 2  TheOnion  No Amount Of Alcohol Good For You, Report Find...           3
# 3  TheOnion  New Pumpkin Spice Channel To Offer Fall-Themed...           4
# 4  TheOnion  RT @ClickHole: A Historic Summit: Donald Trump...           5

# %%
# Target 
target_user = "CBSNews"

# Counter
count = 1

# Variables for holding sentiments
cbs_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cbs_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
cbs_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
cbs_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Wed Aug 29 01:42:28 +0000 2018       0.0    1.000     0.000
# 1    0.5859  Wed Aug 29 01:37:53 +0000 2018       0.0    0.787     0.213
# 2    0.0000  Wed Aug 29 01:29:50 +0000 2018       0.0    1.000     0.000
# 3    0.4019  Wed Aug 29 01:12:20 +0000 2018       0.0    0.881     0.119
# 4    0.4588  Wed Aug 29 01:09:48 +0000 2018       0.0    0.842     0.158
#
#     Source                                               Text  Tweets Ago
# 0  CBSNews  "This race is about every single last one of u...           1
# 1  CBSNews  Tallahassee mayor Andrew Gillum projected to b...           2
# 2  CBSNews  Pfizer is recalling some children's Advil beca...           3
# 3  CBSNews  "You are seeing that this is the complete take...           4
# 4  CBSNews  A 118-year-old Bolivian woman may be the world...           5

# %%
# Target 
target_user = "BBCWorld"

# Counter
count = 1

# Variables for holding sentiments
bbc_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
bbc_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in bbc_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    bbc_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
bbc_sentiments_df = pd.DataFrame.from_dict(bbc_sentiments)
bbc_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.2263  Tue Aug 28 23:32:51 +0000 2018     0.192    0.808     0.000
# 1   -0.5994  Tue Aug 28 22:24:35 +0000 2018     0.302    0.698     0.000
# 2   -0.8176  Tue Aug 28 21:35:18 +0000 2018     0.572    0.289     0.139
# 3   -0.5106  Tue Aug 28 21:12:44 +0000 2018     0.350    0.650     0.000
# 4   -0.5994  Tue Aug 28 21:09:54 +0000 2018     0.302    0.698     0.000
#
#      Source                                               Text  Tweets Ago
# 0  BBCWorld  Chemnitz protests: Far-right on march in east ...           1
# 1  BBCWorld  Puerto Rico increases Hurricane Maria death to...           2
# 2  BBCWorld  Didi blames 'ignorance and pride' for carpool ...           3
# 3  BBCWorld  Canada police arrest teen suspected in German ...           4
# 4  BBCWorld  Scallop war: French and British boats clash in...           5

# %%
# Target 
target_user = "CNN"

# Counter
count = 1

# Variables for holding sentiments
cnn_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cnn_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cnn_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cnn_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
cnn_sentiments_df = pd.DataFrame.from_dict(cnn_sentiments)
cnn_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5859  Wed Aug 29 01:42:31 +0000 2018     0.000    0.774     0.226
# 1    0.0000  Wed Aug 29 01:41:04 +0000 2018     0.000    1.000     0.000
# 2    0.0387  Wed Aug 29 01:31:27 +0000 2018     0.075    0.843     0.082
# 3   -0.2960  Wed Aug 29 01:31:06 +0000 2018     0.104    0.896     0.000
# 4    0.0000  Wed Aug 29 01:19:51 +0000 2018     0.000    1.000     0.000
#
#   Source                                               Text  Tweets Ago
# 0    CNN  Bernie Sanders-backed progressive Andrew Gillu...           1
# 1    CNN  Slowed new construction and a short supply of ...           2
# 2    CNN  RT @CuomoPrimeTime: Former Trump WH Legislativ...           3
# 3    CNN  California will no longer require defendants t...           4
# 4    CNN  "The hive got overcrowded because it was hot a...           5

# %%
# Target 
target_user = "FoxNews"

# Counter
count = 1

# Variables for holding sentiments
fox_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
fox_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in fox_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    fox_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
fox_sentiments_df = pd.DataFrame.from_dict(fox_sentiments)
fox_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5859  Wed Aug 29 01:35:48 +0000 2018     0.000    0.808     0.192
# 1    0.2732  Wed Aug 29 01:30:59 +0000 2018     0.117    0.717     0.166
# 2    0.2023  Wed Aug 29 01:16:02 +0000 2018     0.000    0.886     0.114
# 3    0.4767  Wed Aug 29 01:04:00 +0000 2018     0.000    0.829     0.171
# 4    0.5859  Wed Aug 29 00:52:55 +0000 2018     0.000    0.787     0.213
#
#     Source                                               Text  Tweets Ago
# 0  FoxNews  Tallahassee Mayor @AndrewGillum makes remarks ...           1
# 1  FoxNews  BREAKING: Tallahassee Mayor @AndrewGillum wins...           2
# 2  FoxNews  Sen. @ChrisCoons: 'Significant Body of Work' F...           3
# 3  FoxNews  .@HoustonTexans star @JJWatt's Hurricane Harve...           4
# 4  FoxNews  Rep. @RonDeSantisFL makes remarks after being ...           5

# %%
# Target 
target_user = "nytimes"

# Counter
count = 1

# Variables for holding sentiments
nyt_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
nyt_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in nyt_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    nyt_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": count})
        
    # Add to counter 
    count += 1

# Convert sentiments to DataFrame
nyt_sentiments_df = pd.DataFrame.from_dict(nyt_sentiments)
nyt_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Wed Aug 29 01:42:06 +0000 2018     0.000    1.000       0.0
# 1    0.0000  Wed Aug 29 01:33:00 +0000 2018     0.000    1.000       0.0
# 2    0.0000  Wed Aug 29 01:21:08 +0000 2018     0.000    1.000       0.0
# 3   -0.6395  Wed Aug 29 01:17:05 +0000 2018     0.199    0.801       0.0
# 4    0.0000  Wed Aug 29 01:02:07 +0000 2018     0.000    1.000       0.0
#
#     Source                                               Text  Tweets Ago
# 0  nytimes  RT @jmartNYT: NEW: Fla was already the most co...           1
# 1  nytimes  See full election results and maps from the Fl...           2
# 2  nytimes  Florida's governor race is set: Andrew Gillum,...           3
# 3  nytimes  RT @julieturkewitz: A little boy killed himsel...           4
# 4  nytimes  Florida primary election live results\nhttps:/...           5

# %%
news_tweets_df = pd.concat([onion_sentiments_df, bbc_sentiments_df, cbs_sentiments_df, cnn_sentiments_df,
                            fox_sentiments_df, nyt_sentiments_df], ignore_index=True)

# %%
_theonion = news_tweets_df.loc[news_tweets_df["Source"] == "TheOnion"]["Compound"]
_theonion_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "TheOnion"]["Tweets Ago"]

bbc_com = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"]
bbc_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Tweets Ago"]

cbs_com = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"]
cbs_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Tweets Ago"]

cnn_com = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"]
cnn_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Tweets Ago"]

fox_com = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"]
fox_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Tweets Ago"]

nyt_com = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"]
nyt_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Tweets Ago"]

# Use "ax" functions to modify the scatterplot grid and colors
fig, ax=plt.subplots()

ax.scatter(_theonion_tweets, _theonion, s=75, marker ="o", color="purple", alpha=0.75, edgecolors="black")
ax.scatter(bbc_tweets, bbc_com, s=75, marker ="o", color="lightskyblue", alpha=0.75, edgecolors="black")
ax.scatter(cbs_tweets, cbs_com, s=75, marker ="o", color="green", alpha=0.75, edgecolors="black")
ax.scatter(cnn_tweets, cnn_com, s=75, marker ="o", color="red", alpha=0.75, edgecolors="black")
ax.scatter(fox_tweets, fox_com, s=75, marker ="o", color="blue", alpha=0.75, edgecolors="black")
ax.scatter(nyt_tweets, nyt_com, s=75, marker ="o", color="yellow", alpha=0.75, edgecolors="black")

ax.set_xlim(100,0)
ax.set_ylim(-1, 1)
ax.set_facecolor("lightgrey")


# Set the grid lines behind the plots and remove unneccessary spines
ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([-1.0, -0.50, 0.0, 0.50, 1.00])
plt.tick_params(bottom=False, left=False)

ax.grid(color="white")

plt.title("Sentiment Analysis of Media Tweets (8/28/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Create a legend
# Incorporate a text label regarding circle size

theOnion = plt.scatter([],[], s=75, marker = "o", color = "purple", edgecolors="black")
bbc = plt.scatter([],[], s=75, marker = "o", color = "lightskyblue", edgecolors="black")
cbs = plt.scatter([],[], s=75, marker = "o", color = "green", edgecolors="black")
cnn = plt.scatter([],[], s=75, marker = "o", color = "red", edgecolors="black")
fox = plt.scatter([],[], s=75, marker = "o", color = "blue", edgecolors="black")
ny_times = plt.scatter([],[], s=75, marker = "o", color = "gold", edgecolors="black")

plt.legend((bbc, cbs, cnn, fox, ny_times), ("The Onion","BBC", "CBS", "CNN", "Fox", "NY Times"), frameon=False, title="Media Sources", bbox_to_anchor=(1.01, 1))

plt.show()

# %%
#Setting Subplot for visual
fig, ax=plt.subplots()

theonion_mean = news_tweets_df.loc[news_tweets_df["Source"] == "TheOnion"]["Compound"].mean()
bbc_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"].mean()
cbs_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"].mean()
cnn_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"].mean()
fox_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"].mean()
nyt_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"].mean()

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_facecolor("lightgrey")

plt.tick_params(bottom=False, left=False)                            

plt.bar("The Onion", bbc_com_mean, color ="purple", edgecolor="grey", align="center")
plt.bar("BBC", bbc_com_mean, color ="lightskyblue", edgecolor="grey", align="center")
plt.bar("CBS", cbs_com_mean, color ="green", edgecolor="grey", align="center")
plt.bar("CNN", cnn_com_mean, color ="red", edgecolor="grey", align="center")
plt.bar("Fox", fox_com_mean, color ="blue", edgecolor="grey", align="center")
plt.bar("NYT", nyt_com_mean, color ="gold", edgecolor="grey", align="center")

plt.title("Overall Media Sentiment Based on Twitter (8/28/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height() 
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 10
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.2f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,
        (x_value, y_value),
        xytext=(0, space),
        textcoords="offset points",
        ha='center',
        va=va)
    
#Set this so output file does not cut off legend
fig.tight_layout()

# Export graph for presentation
plt.savefig("Vader.png")

plt.show()
